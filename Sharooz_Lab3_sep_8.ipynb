# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadsharooz2004-design/Client_Requirement_Agent/blob/main/Sharooz_Lab3_sep_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
,!pip install -U google-genai
from google import genai
client = genai.Client(api_key="")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.58.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Gemini Travel Agent Started (type 'exit' to stop)
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Agent:
#  Assalam-o-Alaikum! Welcome to Pakistan Tourism. As your professional travel agent, I am thrilled to help you plan an unforgettable, pocket-friendly adventure.
#
# Since you are looking for a student-friendly budget, I highly recommend **Hunza Valley (Gilgit-Baltistan)**. It is one of the most beautiful, safest, and most literate regions in Pakistan, making it the perfect destination for student groups.
#
# Here is your detailed, easy-to-follow travel plan from Islamabad (the main gateway to the North) to Hunza.
#
# ---
#
# ### 1. Destination Overview
# **Hunza Valley** is a mountainous valley situated in the northern part of Gilgit-Baltistan. Surrounded by majestic peaks like Rakaposhi and Ladyfinger, Hunza is famous for its turquoise lakes, historic forts, friendly locals, and vibrant culture. For students, it offers the perfect blend of adventure, photography, peace, and cultural learning.
# *   **Best Time to Visit:** May to October (for pleasant weather) or October to November (for autumn colors).
# *   **Ideal Trip Duration:** 5 to 7 days.
#
# ---
#
# ### 2. Budget Travel Options (From Islamabad to Hunza/Gilgit)
#
# To reach Hunza, you first travel to Gilgit (the main transit city) or directly to Karimabad (Hunza).
#
# *   **By Train (For students coming from Karachi/Lahore to Islamabad):**
#     *   Take the train to Rawalpindi/Islamabad first.
#     *   *Economy Class:* **PKR 2,500 – 4,500** (depending on the city of origin). Always ask for the 50% Student Discount on Pakistan Railways by showing your original student ID card.
# *   **By Bus (Most Budget-Friendly):**
#     *   Take a direct bus (NATCO or Faisal Movers) from Islamabad to Gilgit/Hunza via the Karakoram Highway or Babusar Top.
#     *   *Approx. Cost:* **PKR 4,500 – 6,000** (One-way).
# *   **By Flight (Fastest but expensive):**
#     *   PIA operates daily flights from Islamabad to Gilgit (subject to weather).
#     *   *Approx. Cost:* **PKR 18,000 – 28,000** (One-way).
# *   **Local Transport (Within Hunza):**
#     *   Do not rent private cars. Use local shared *Hiace* vans running between Gilgit, Karimabad, and Upper Hunza (Gojal).
#     *   *Approx. Cost:* **PKR 300 – 500** per stop.
#
# ---
#
# ### 3. Places to Visit
#
# *   **Baltit Fort & Altit Fort:** 800-year-old architectural marvels. They offer sweeping views of the valley. *(Tip: Great for history buffs and photography).*
# *   **Attabad Lake:** A stunning, bright blue lake created by a landslide in 2010. You can enjoy a budget-friendly group boat ride here.
# *   **Passu Cones & Hussaini Suspension Bridge:** The iconic pointy peaks (Passu Cones) make the perfect background for group photos. Nearby, test your courage by walking on the Hussaini Suspension Bridge, considered one of the most adventurous bridges in the world.
# *   **Karimabad Bazaar:** A cobblestone street lined with cafes, handicraft shops, and gemstone stores. Perfect for evening strolls.
# *   **Eagle’s Nest (Duiker):** The highest viewpoint in Hunza. Go here at sunset or sunrise to see the golden light hitting Rakaposhi and Golden Peak.
#
# ---
#
# ### 4. Food Suggestions (Must-Try Local Dishes)
#
# Hunza’s food is organic, unique, and very affordable if you eat at local dhabas.
#
# *   **Chapshuro (The Hunza Pizza):** A crusty flatbread stuffed with seasoned minced meat (beef or yak) and onions. It is extremely filling and cheap.
#     *   *Approx. Cost:* **PKR 200 – 350** per Chapshuro (easily shared by two).
# *   **Dowodo:** A traditional, warm noodle soup made with handmade wheat noodles and meat broth. Perfect for chilly evenings.
#     *   *Approx. Cost:* **PKR 250 – 400** per bowl.
# *   **Mamtu (Steamed Dumplings):** Beef or mutton dumplings steamed to perfection, served with black pepper and vinegar.
#     *   *Approx. Cost:* **PKR 300 – 500** per plate (usually contains 6 to 8 pieces).
# *   **Tumuro Tea:** A local herbal tea made from wild thyme collected from the mountains. It helps with altitude sickness.
#     *   *Approx. Cost:* **PKR 70 – 120** per cup.
# *   **Local Apricot Cake:** Available at the famous *Cafe de Hunza* in Karimabad.
#
# ---
#
# ### 5. Money-Saving Tips for Students
#
# *   **The Power of Student IDs:** Always carry your active University/College ID card. Altit and Baltit Forts offer up to a **50% discount** on entry tickets for Pakistani students.
# *   **Group Sharing is Caring:** Travel in a group of 4 to 6 friends. This allows you to split the cost of hotel rooms (triple/quad sharing) and local jeep rentals.
# *   **Opt for Camping:** Instead of expensive hotels, stay in camps. Camping sites at Rakaposhi View Point (Ghulmet) or Passu are incredibly cheap (**PKR 1,500 – 2,500** per night, including tent rental).
# *   **Eat Where the Locals Eat:** Avoid high-end tourist restaurants. Eat at small local *dhabas* in Karimabad and Aliabad where a full meal costs less than **PKR 400**.
# *   **Travel Light:** Carrying fewer bags makes it easier to hop on and off local public transport (Hiace/coasters), saving you from hiring private taxis.
#
# Have a safe and wonderful journey! Let me know if you would like me to adjust this plan or provide a day-by-day itinerary.
