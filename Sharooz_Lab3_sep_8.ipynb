# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadsharooz2004-design/Client_Requirement_Agent/blob/main/Sharooz_Lab3_sep_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

from google.colab import userdata

client = genai.Client(api_key=userdata.get("GEMINI_API_KEY"))


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: hy
# Error: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# You: hy
#
# Agent:
#  Hello! Welcome to Pakistan Tourism. As your dedicated travel agent, I am thrilled to help you plan an unforgettable, pocket-friendly adventure.
#
# Since you are looking for a student-friendly budget plan, I have designed the perfect itinerary for **Hunza Valley (Gilgit-Baltistan)**. It is one of the most beautiful, safest, and most culturally rich destinations in Pakistan—perfect for a student group!
#
# Here is your detailed, easy-to-follow travel plan:
#
# ---
#
# ### 1. Destination Overview: Hunza Valley
# ...

# %%
def project_requirement_agent(user_input):

    prompt = f"""
You are a professional Web Development Requirement-Gathering Agent.

Help clients by understanding their project needs and generating a clear
Project Requirement Summary based on what they tell you.

The summary should include:
- Project Overview
- Key Features Needed
- Suggested Tech Stack (WordPress/Shopify/Custom)
- Estimated Timeline
- Next Steps for the client

If the client has not given enough details (like budget, deadline, or project type),
ask a follow-up question instead of guessing.

Give simple and clear answers.

Client message: {user_input}

Requirement Agent:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("Client Requirement Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = project_requirement_agent(user)
        print("\nRequirement Agent:\n", reply, "\n")
    except Exception as e:
        print("Error:", e)
# Out:
# Client Requirement Agent Started (type 'exit' to stop)
#
# You:    I need a WordPress site for my bakery, budget 30000, deadline 2 weeks
#
# Requirement Agent:
#  Hello! I would love to help you get your bakery website up and running.
#
# To make sure I provide you with the most accurate Project Requirement Summary, I just need a few quick clarifications:
#
# 1. **Budget Currency:** What currency is your 30,000 budget in (e.g., USD, INR, PHP, etc.)?
# 2. **Website Features:** Do you want customers to be able to order and pay for baked goods directly on the website (e-commerce), or do you just need a simple website to show your menu, location, and contact info?
# 3. **Content Readiness:** Since we have a tight 2-week deadline, do you already have your logo, high-quality photos of your baked goods, and text ready?
#
# Once you let me know, I will put together your customized Project Requirement Summary!
#
# You: exit
# Goodbye
