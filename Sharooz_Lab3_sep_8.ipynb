# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadsharooz2004-design/Client_Requirement_Agent/blob/main/Sharooz_Lab3_sep_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai
client = genai.Client(api_key="")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Gemini Travel Agent Started (type 'exit' to stop)
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Agent:
#  Hello! Assalamualaikum! As your professional Pakistan travel consultant, I welcome you!
#
# Since you are looking for an exciting yet budget-friendly trip perfect for students, I highly recommend **Hunza Valley** (located in Gilgit-Baltistan). It is known as the "Heaven on Earth," offering majestic mountain views, rich culture, and unmatched safety for young travelers.
#
# Here is a complete, student-friendly travel plan from **Islamabad to Hunza Valley**.
#
# ---
#
# ### 1. Destination Overview
# Hunza Valley is a mountainous valley situated in the northern part of Gilgit-Baltistan. It is famous for its towering peaks (like Rakaposhi and Ladyfinger), turquoise lakes, ancient forts, and incredibly hospitable locals. Hunza has a nearly 100% literacy rate, making it one of the safest and most progressive tourist destinations in Pakistan.
# *   **Best Time to Visit:** May to October (for pleasant weather) or Autumn (October–November) for golden foliage.
# *   **Vibe:** Adventurous, peaceful, and culturally rich.
#
# ---
#
# ### 2. Budget Travel Options (Islamabad to Gilgit/Hunza)
# *Note: Prices are approximate and subject to seasonal changes.*
#
# *   **Option A: The Budget Train (For students coming from Lahore/Karachi to Rawalpindi first)**
#     *   **Karachi to Rawalpindi (Tezgam/Green Line Economy):** PKR 3,500 – PKR 5,000 (one-way).
#     *   **Lahore to Rawalpindi (Subak Raftar/Express Economy):** PKR 1,200 – PKR 1,800 (one-way).
# *   **Option B: The Road Trip (Bus - Most Popular for Students)**
#     *   You can take the **NATCO** (Government transport) or **Faisal Movers** from Islamabad to Gilgit.
#     *   **Cost:** PKR 4,500 – PKR 6,000 (one-way).
#     *   **Travel Time:** 16–18 hours via the scenic Karakoram Highway (KKH) or Babusar Top (in summer).
#     *   *From Gilgit to Hunza (Karimabad):* Take a local shared Hiace/van for just **PKR 500 – PKR 800**.
# *   **Option C: Flight (Fastest but expensive)**
#     *   PIA operates flights from Islamabad to Gilgit (subject to weather).
#     *   **Cost:** PKR 16,000 – PKR 25,000 (one-way student discounts are sometimes available on PIA if booked directly through their office).
#
# ---
#
# ### 3. Places to Visit
# Here are the absolute must-visit spots in Hunza that won't break the bank:
#
# *   **Baltit Fort & Altit Fort:** 800-year-old architectural marvels. They offer a deep dive into the history of the Mirs (rulers) of Hunza. *Ticket: Approx. PKR 400 for students (show your ID).*
# *   **Karimabad Bazaar:** A cobblestone street filled with local gemstone shops, cafes, and handicrafts. Great for window shopping and photography.
# *   **Eagle’s Nest (Duiker):** The highest viewpoint in Hunza. You can see 11 spectacular peaks over 6,000 meters, including Rakaposhi and Golden Peak. Go here for a breathtaking sunset.
# *   **Attabad Lake:** A stunning, bright-blue lake formed in 2010. You can enjoy a shared boat ride here for about **PKR 1,000 per person**.
# *   **Passu Cones & Suspension Bridge:** The iconic pointed mountain peaks. Walk on the thrilling Passu Suspension Bridge over the Hunza River (entry is free/nominal fee of PKR 100-200).
#
# ---
#
# ### 4. Food Suggestions
# Hunza’s local cuisine is organic, delicious, and highly energetic.
#
# *   **Chapshuro (The Hunza Pizza):** A crusty flatbread stuffed with spiced minced meat (beef or yak) and onions. It is incredibly filling and costs only **PKR 300 – PKR 500** (easily shares between two).
# *   **Tumuro Tea:** A local herbal tea made from wild thyme gathered from the mountains. It helps with altitude sickness and costs only **PKR 100 – PKR 150** a cup.
# *   **Downdo (Noodle Soup):** Homemade wheat noodles in a warm soup, perfect for chilly evenings. (Approx. **PKR 300**).
# *   **Fresh/Dried Apricots & Cherries:** You can buy bags of organic dried apricots or fresh cherries for as cheap as **PKR 200 – PKR 400** directly from local farmers.
#
# ---
#
# ### 5. Money-Saving Tips for Students
#
# 1.  **Flash Your Student ID:** Always carry your university/college ID card. You can get up to a 50% discount on entry tickets to historical forts and national parks.
# 2.  **Travel in a Group (Squad of 4 or more):** Hotel rooms in Karimabad cost around PKR 3,000–5,000 per night. If you split a quad-room (4 beds), it costs only **PKR 1,000 per person**.
# 3.  **Use Shared Public Transport:** Instead of renting a private Prado or Jeep (which costs PKR 8,000+ per day), use the local "Hiace" vans that run regularly between Gilgit, Aliabad, Karimabad, and Passu.
# 4.  **Ditch Luxury Cafes for Dhabas:** Skip the fancy tourist restaurants. Eat at local dhabas in Aliabad or Karimabad bazaar where a plate of Daal Chawal or Chicken Karahi is highly affordable.
# 5.  **Camp Out:** If you are adventurous, rent a tent at Attabad Lake or Passu for a fraction of the cost of a hotel room.
#
# Have a safe and memorable trip! Let me know if you need help planning a day-by-day itinerary or calculating the exact total cost!
